# %%
import pandas as pd

# %%
s = pd.Series([1,2,3,4,5])
print(s[4])
# Out:
# 5

# %%
new_series = pd.Series([23,24,25,26],index=["Adam","Eve","Charlie","Mohan"])
print(new_series.index)
# Out:
# Index(['Adam', 'Eve', 'Charlie', 'Mohan'], dtype='object')

# %% [markdown]
# Series Properties

# %%
for i in range(len(s)):
    print(s[i]+i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# Homogeneous
# Vectorization
# Handle Missing values with NaN
# Mutable Elements Value but Immutable size

# %%
# DataFrame

# %%
df = pd.DataFrame([['Tarun',21],['Raj',21],['Sarthak',21]],columns =['Name','Age'],index=range(1,4))
df.nunique()
# Out:
# Name    3
# Age     1
# dtype: int64

# %%
data = pd.read_csv('globalAirQuality.csv')
data
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df.sample(5)
# Out:
#                         timestamp country          city  latitude  longitude  \
# 5763   2025-11-04 21:25:17.554219      SA        Riyadh    24.714     46.675
# 8563   2025-11-16 13:25:17.554219      JP         Tokyo    35.676    139.650
# 16686  2025-11-10 00:25:17.554219      PL        Warsaw    52.230     21.012
# 3745   2025-11-10 19:25:17.554219      AR  Buenos Aires   -34.604    -58.382
# 11803  2025-11-16 13:25:17.554219      ID       Jakarta    -6.209    106.846
#
#          pm25    pm10     no2    so2      o3     co  aqi  temperature  \
# 5763   37.878  45.209  25.940  5.730  69.826  0.914   75       35.940
# 8563   55.729  62.054  26.891  5.149  22.886  0.866  111        7.795
# 16686  16.634  55.575  27.879  3.988  31.593  0.539   69       23.342
# 3745   17.692  90.853  52.002  5.973  65.411  0.601  130       31.946
# 11803  40.115  87.197  16.126  7.055  18.948  0.952   87       14.713
#
#        humidity  wind_speed
# 5763     54.665       1.067
# ...

# %%
df.loc[:3]
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
# 2  2025-11-04 20:25:17.554219      US  New York    40.713    -74.006  42.250
# 3  2025-11-04 21:25:17.554219      US  New York    40.713    -74.006  30.403
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
# 2   82.553  26.935  9.538  23.320  0.977   84       31.833    62.783
# 3   79.951  63.536  7.609  31.369  0.230  158       23.140    89.153
#
#    wind_speed
# 0       3.725
# 1       8.969
# 2       9.650
# 3       8.956

# %%
df.iat[2,1]
# Out:
# 'US'

# %%
df[['longitude','country','aqi']]
# Out:
#        longitude country  aqi
# 0        -74.006      US  108
# 1        -74.006      US   90
# 2        -74.006      US   84
# 3        -74.006      US  158
# 4        -74.006      US   97
# ...          ...     ...  ...
# 17995      8.542      CH  103
# 17996      8.542      CH  105
# 17997      8.542      CH  122
# 17998      8.542      CH   95
# 17999      8.542      CH   88
#
# [18000 rows x 3 columns]

# %%
df[(df['city']=='Delhi') & (df['aqi']<50)]
# Out:
#                        timestamp country   city  latitude  longitude    pm25  \
# 6918  2025-11-08 00:25:17.554219      IN  Delhi    28.704     77.102  17.299
# 6949  2025-11-09 07:25:17.554219      IN  Delhi    28.704     77.102  14.007
# 7023  2025-11-12 09:25:17.554219      IN  Delhi    28.704     77.102  24.033
#
#         pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 6918  20.153  16.289  9.517  51.996  0.319   40       29.219    87.467
# 6949  46.143  15.781  5.088  70.074  0.656   46       24.130    51.745
# 7023  34.610  16.538  6.835  58.051  0.706   48       36.286    28.847
#
#       wind_speed
# 6918       3.501
# 6949       6.791
# 7023       6.795

# %%
aqi_val = 100
df.query("aqi>@aqi_val" )
len(df.columns)
# Out:
# 15

# %%
df.isnull().sum()
# Out:
# timestamp      0
# country        0
# city           0
# latitude       0
# longitude      0
# pm25           0
# pm10           0
# no2            0
# so2            0
# o3             0
# co             0
# aqi            0
# temperature    0
# humidity       0
# wind_speed     0
# dtype: int64

# %%
df.dtypes
# Out:
# timestamp       object
# country         object
# city            object
# latitude       float64
# longitude      float64
# pm25           float64
# pm10           float64
# no2            float64
# so2            float64
# o3             float64
# co             float64
# aqi              int64
# temperature    float64
# humidity       float64
# wind_speed     float64
# dtype: object

# %%
df2 = pd.read_json("store_data.json")
df2
# Out:
#                  name    age review  country
# 0       Alice Johnson   28.0    4.5      USA
# 1         brian smith   34.0   Five      USA
# 2     Charlie Brown      NaN    two   Canada
# 3        Diana Prince  200.0    3.5       US
# 4                None   29.0   Zero       UK
# 5                EVAN   -5.0  thRee  germany

# %%
df2.isnull().sum()
# Out:
# name       1
# age        1
# review     0
# country    0
# dtype: int64

# %%
df2
# Out:
#                  name    age review  country
# 0       Alice Johnson   28.0    4.5      USA
# 1         brian smith   34.0   Five      USA
# 2     Charlie Brown      NaN    two   Canada
# 3        Diana Prince  200.0    3.5       US
# 4                None   29.0   Zero       UK
# 5                EVAN   -5.0  thRee  germany
