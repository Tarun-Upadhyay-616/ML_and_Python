# %%
import pandas as pd

# %%
s = pd.Series([1,2,3,4,5])
print(s[4])
# Out:
# 5

# %%
new_series = pd.Series([23,24,25,26],index=["Adam","Eve","Charlie","Mohan"])
print(new_series.index)
# Out:
# Index(['Adam', 'Eve', 'Charlie', 'Mohan'], dtype='object')

# %% [markdown]
# Series Properties

# %%
for i in range(len(s)):
    print(s[i]+i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# Homogeneous
# Vectorization
# Handle Missing values with NaN
# Mutable Elements Value but Immutable size

# %%
# DataFrame

# %%
df = pd.DataFrame([['Tarun',21],['Raj',21],['Sarthak',21]],columns =['Name','Age'],index=range(1,4))
df.nunique()
# Out:
# Name    3
# Age     1
# dtype: int64

# %%
data = pd.read_csv('datasets/globalAirQuality.csv')
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data = pd.read_csv('datasets/globalAirQuality.csv')
#       2 data
#
# NameError: name 'pd' is not defined

# %%
df = pd.DataFrame(data)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.DataFrame(data)
#       2 df
#
# NameError: name 'pd' is not defined

# %%
df.sample(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.sample(5)
#
# NameError: name 'df' is not defined

# %%
df.loc[:3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.loc[:3]
#
# NameError: name 'df' is not defined

# %%
df.iat[2,1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.iat[2,1]
#
# NameError: name 'df' is not defined

# %%
df[['longitude','country','aqi']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df[['longitude','country','aqi']]
#
# NameError: name 'df' is not defined

# %%
df[(df['city']=='Delhi') & (df['aqi']<50)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df[(df['city']=='Delhi') & (df['aqi']<50)]
#
# NameError: name 'df' is not defined

# %%
aqi_val = 100
df.query("aqi>@aqi_val" )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 aqi_val = 100
# ----> 2 df.query("aqi>@aqi_val" )
#
# NameError: name 'df' is not defined

# %%
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df.isnull().sum()
#
# NameError: name 'df' is not defined

# %%
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.dtypes
#
# NameError: name 'df' is not defined

# %%
df2 = pd.read_json("store_data.json")
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df2 = pd.read_json("store_data.json")
#       2 df2
#
# NameError: name 'pd' is not defined

# %%
df2.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df2.isnull().sum()
#
# NameError: name 'df2' is not defined

# %%
df2
