# %% [markdown]
# # DBSCAN

# %%
from sklearn.datasets import make_moons
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
import seaborn as sns

# %%
X,y = make_moons(
    n_samples = 2000,
)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[ 0.01262009, -1.25967819],
#        [-0.10923657, -1.12151445],
#        [-1.4637441 ,  0.79027789],
#        ...,
#        [-0.80613529,  1.47807453],
#        [-0.7237766 ,  1.5019068 ],
#        [ 1.64619278, -0.25756353]])

# %%
sns.scatterplot(x=X_scaled[:,0],y=X_scaled[:,1],c=y)
# Out:
# <Axes: >

# %%
dbs = DBSCAN(
    eps = 0.8,
    min_samples = 8
)
labels = dbs.fit_predict(X_scaled)
sns.scatterplot(x=X_scaled[:,0],y=X_scaled[:,1],c=labels)
# Out:
# <Axes: >
